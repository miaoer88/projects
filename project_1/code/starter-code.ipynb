# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The new format for the SAT was released in March 2016. Changes made to the SAT in 2016 have made it easier. As such, there might be switch in participation rate across the states between ACT and SAT. Therefore, the purpose of the project is to review the trend of participation rate from year 2017 to 2019 for both ACT/SAT and to identify if there is increase of participation rate on SAT.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# A new version of the SAT is in place as of March 2016 that includes dramatic revisions to the test's scoring and content. The old 2400-point scale has been replaced by the 1600-point system that was in use prior to the last major round of revisions in 2005. The essay, which is now optional, is scored separately. Changes made to the SAT in 2016 have made it easier.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 8 datasets included in the [`data`](./data/) the project for analysis from year 2017 and 2019 on ACT and SAT.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
import pandas as pd
import numpy as np

# %%
sat_ca = pd.read_csv('../data/sat_2019_ca.csv')

# %%
sat_ca
# Out:
#                CDS  CCode     CDCode      SCode RType  \
# 0     6.615981e+12    6.0   661598.0   630046.0     S
# 1     6.616061e+12    6.0   661606.0   634758.0     S
# 2     1.964733e+13   19.0  1964733.0  1930924.0     S
# 3     1.964733e+13   19.0  1964733.0  1931476.0     S
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# ...            ...    ...        ...        ...   ...
# 2575  5.772678e+13   57.0  5772678.0        0.0     D
# 2576  7.000000e+12    7.0   700000.0        0.0     C
# 2577  1.700000e+13   17.0  1700000.0        0.0     C
# 2578  3.800000e+13   38.0  3800000.0        0.0     C
# 2579           NaN    NaN        NaN        NaN   NaN
#
#                         SName                DName          CName  Enroll12  \
# 0     Colusa Alternative Home       Colusa Unified         Colusa      18.0
# 1             Maxwell Sr High      Maxwell Unified         Colusa      29.0
# 2         Belmont Senior High  Los Angeles Unified    Los Angeles     206.0
# ...

# %%
sat_ca.describe()
# Out:
#                 CDS        CCode        CDCode         SCode       Enroll12  \
# count  2.579000e+03  2579.000000  2.579000e+03  2.579000e+03    2579.000000
# mean   2.915139e+13    28.519581  2.915138e+06  1.544913e+06     748.155487
# std    1.428328e+13    14.258173  1.428327e+06  1.812049e+06   10095.758681
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964725e+13    19.000000  1.964725e+06  1.025080e+05      63.000000
# 50%    3.066597e+13    30.000000  3.066597e+06  1.377860e+05     171.000000
# 75%    3.777103e+13    37.000000  3.777103e+06  3.037422e+06     462.000000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  489650.000000
#
#         NumTSTTakr12       Enroll11   NumTSTTakr11  Unnamed: 25
# count    2579.000000    2579.000000    2579.000000          0.0
# mean      264.274137     730.865452     320.473052          NaN
# std      3568.205236    9792.971460    4396.615761          NaN
# ...

# %%
from numpy.random import normal

# %%
def mean(stats):
    n = len(stats)
    mean = sum(stats) / n
    return mean

stats = normal(loc=25, scale=5, size=2580)
round(mean(stats))
# Out:
# 25

# %%
import scipy.stats as stats

# %%
Y = stats.norm(25,5)

# %%
print(Y.mean())
print(Y.std())
# Out:
# 25.0
# 5.0

# %%
act_ca = pd.read_csv('../data/act_2019_ca.csv')

# %%
act_ca.columns
# Out:
# Index(['CDS', 'CCode', 'CDCode', 'SCode', 'RType', 'SName', 'DName', 'CName',
#        'Enroll12', 'NumTstTakr', 'AvgScrRead', 'AvgScrEng', 'AvgScrMath',
#        'AvgScrSci', 'NumGE21', 'PctGE21', 'Year', 'Unnamed: 17'],
#       dtype='object')

# %%
sat_ca.columns
# Out:
# Index(['CDS', 'CCode', 'CDCode', 'SCode', 'RType', 'SName', 'DName', 'CName',
#        'Enroll12', 'NumTSTTakr12', 'NumERWBenchmark12', 'PctERWBenchmark12',
#        'NumMathBenchmark12', 'PctMathBenchmark12', 'Enroll11', 'NumTSTTakr11',
#        'NumERWBenchmark11', 'PctERWBenchmark11', 'NumMathBenchmark11',
#        'PctMathBenchmark11', 'TotNumBothBenchmark12', 'PctBothBenchmark12',
#        'TotNumBothBenchmark11', 'PctBothBenchmark11', 'Year', 'Unnamed: 25'],
#       dtype='object')

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def get_std_dev(stats):
    n = len(stats)
    mean = sum(stats) / n
    var = sum((x - mean)**2 for x in stats) / n
    std_dev = var ** 0.5
    return std_dev

stats = normal(loc=25, scale=5, size=2579)
round(get_std_dev(stats))
# Out:
# 5

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def percent_to_float(x):
    return float(x.strip('%'))/100

x = '95%'
percent_to_float(x)
# Out:
# 0.95

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
act_19 = pd.read_csv('../data/act_2019.csv')

# %%
act_19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
act_19.shape
# Out:
# (52, 3)

# %%
act_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act_19.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
act_19[act_19.columns[1:]] = act_19[act_19.columns[1:]].replace('[\%,]', '', regex=True).astype(float)

# %%
act_19.head()
# Out:
#         State  Participation  Composite
# 0     Alabama          100.0       18.9
# 1      Alaska           38.0       20.1
# 2     Arizona           73.0       19.0
# 3    Arkansas          100.0       19.3
# 4  California           23.0       22.6

# %%
act_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
act_19.to_csv('../data/act_19_cleaned.csv')

# %%
sat_19 = pd.read_csv('../data/sat_2019.csv')

# %%
sat_19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_19.shape
# Out:
# (53, 5)

# %%
sat_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
sat_19.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
sat_19['Participation Rate'].unique()
# Out:
# array(['7%', '41%', '31%', '6%', '63%', '100%', '94%', '71%', '54%',
#        '66%', '3%', '4%', '5%', '99%', '82%', '81%', '9%', '20%', '95%',
#        '18%', '79%', '51%', '2%', '19%', '22%', '70%', '—', '68%'],
#       dtype=object)

# %%
sat_19['Participation Rate'] = [np.nan if paricipation_rate=='—' else str(paricipation_rate) for paricipation_rate in sat_19['Participation Rate'].values]
sat_19['Participation Rate'].sort_values(ascending=False)
# Out:
# 50     99%
# 19     99%
# 29     95%
# 8      94%
# 26      9%
# 30     82%
# 20     82%
# 21     81%
# 32     79%
# 10     71%
# 49     70%
# 38     70%
# 0       7%
# 43      7%
# 44     68%
# 41     68%
# 48     68%
# 14     66%
# 46     66%
# 4      63%
# 3       6%
# 11     54%
# 37     51%
# 33     51%
# 18      5%
# 1      41%
# 45      4%
# 25      4%
# 23      4%
# 17      4%
# 16      4%
# 2      31%
# 52      3%
# 27      3%
# 24      3%
# 51      3%
# 42      3%
# 15      3%
# 36     22%
# 28     20%
# 34      2%
# 35     19%
# 31     18%
# 13    100%
# 12    100%
# 9     100%
# 7     100%
# 6     100%
# 5     100%
# 22    100%
# 40    100%
# 39     NaN
# 47     NaN
# Name: Participation Rate, dtype: object

# %%
sat_19[sat_19.columns[1:]] = sat_19[sat_19.columns[1:]].replace('[\%,]', '', regex=True).astype(float)

# %%
sat_19.head()
# Out:
#         State  Participation Rate   EBRW   Math   Total
# 0     Alabama                 7.0  583.0  560.0  1143.0
# 1      Alaska                41.0  556.0  541.0  1097.0
# 2     Arizona                31.0  569.0  565.0  1134.0
# 3    Arkansas                 6.0  582.0  559.0  1141.0
# 4  California                63.0  534.0  531.0  1065.0

# %%
sat_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  51 non-null     float64
#  2   EBRW                53 non-null     float64
#  3   Math                53 non-null     float64
#  4   Total               53 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.2+ KB

# %%
sat_19.rename(columns={
    'Participation Rate': 'Participation'
}, inplace=True)
sat_19.head()
# Out:
#         State  Participation   EBRW   Math   Total
# 0     Alabama            7.0  583.0  560.0  1143.0
# 1      Alaska           41.0  556.0  541.0  1097.0
# 2     Arizona           31.0  569.0  565.0  1134.0
# 3    Arkansas            6.0  582.0  559.0  1141.0
# 4  California           63.0  534.0  531.0  1065.0

# %%
act_19.isna().sum()/len(act_19)
# Out:
# State            0.0
# Participation    0.0
# Composite        0.0
# dtype: float64

# %%
sat_19.isna().sum()/len(sat_19)
# Out:
# State            0.000000
# Participation    0.037736
# EBRW             0.000000
# Math             0.000000
# Total            0.000000
# dtype: float64

# %%
sat_19.dropna(subset=['Participation'], inplace=True)

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
sat_19.to_csv('../data/sat_19_cleaned.csv')

# %%
act_18 = pd.read_csv('../data/act_2018.csv')
act_18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act_18.shape
# Out:
# (52, 3)

# %%
act_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act_18[act_18.columns[1:]] = act_18[act_18.columns[1:]].replace('[\%,]', '', regex=True).astype(float)

# %%
act_18.head()
# Out:
#         State  Participation  Composite
# 0     Alabama          100.0       19.1
# 1      Alaska           33.0       20.8
# 2     Arizona           66.0       19.2
# 3    Arkansas          100.0       19.4
# 4  California           27.0       22.7

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
act_18.to_csv('../data/act_18_cleaned.csv')

# %%
act_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
sat_18 = pd.read_csv('../data/sat_2018.csv')
sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_18.shape
# Out:
# (51, 5)

# %%
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_18[sat_18.columns[1:]] = sat_18[sat_18.columns[1:]].replace('[\%,]', '', regex=True).astype(float)

# %%
sat_18.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing   Math  \
# 0     Alabama            6.0                               595.0  571.0
# 1      Alaska           43.0                               562.0  544.0
# 2     Arizona           29.0                               577.0  572.0
# 3    Arkansas            5.0                               592.0  576.0
# 4  California           60.0                               540.0  536.0
#
#     Total
# 0  1166.0
# 1  1106.0
# 2  1149.0
# 3  1169.0
# 4  1076.0

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
sat_18.to_csv('../data/sat_18_cleaned.csv')

# %%
act_17 = pd.read_csv('../data/act_2017.csv')
act_17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_17.shape
# Out:
# (52, 7)

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_17['Participation'].unique()
# Out:
# array([' 60%', '100%', '65%', '62%', '31%', '18%', '32%', '73%', '55%',
#        '90%', '38%', '93%', '35%', '67%', '8%', '28%', '29%', '84%',
#        '34%', '66%', '98%', '75%', '40%', '23%', '21%', '80%', '45%',
#        '69%'], dtype=object)

# %%
act_17[act_17.columns[1:]] = act_17[act_17.columns[1:]].replace(' ', '', regex=True)

# %%
act_17['Participation'].unique()
# Out:
# array(['60%', '100%', '65%', '62%', '31%', '18%', '32%', '73%', '55%',
#        '90%', '38%', '93%', '35%', '67%', '8%', '28%', '29%', '84%',
#        '34%', '66%', '98%', '75%', '40%', '23%', '21%', '80%', '45%',
#        '69%'], dtype=object)

# %%
act_17['Composite'].unique()
# Out:
# array(['21.0', '19.2', '19.8', '19.7', '19.4', '22.8', '20.8', '25.2',
#        '24.1', '24.2', '21.4', '19.0', '22.3', '22.6', '21.9', '21.7',
#        '20.0', '19.5', '24.3', '23.6', '25.4', '21.5', '18.6', '20.4',
#        '20.3', '17.8', '25.5', '23.9', '19.1', '22.0', '21.8', '23.7',
#        '24.0', '18.7', '20.7', '23.8', '20.5', '20.2x'], dtype=object)

# %%
act_17[act_17.columns[1:]] = act_17[act_17.columns[1:]].replace('x', '', regex=True)

# %%
act_17[act_17.columns[1:]] = act_17[act_17.columns[1:]].replace('[\%,]', '', regex=True).astype(float)

# %%
act_17.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           60.0     20.3  20.7     21.4     21.0       21.0
# 1   Alabama          100.0     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           65.0     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           62.0     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas          100.0     18.9  19.0     19.7     19.5       19.4

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
act_17.to_csv('../data/act_17_cleaned.csv')

# %%
sat_17 = pd.read_csv('../data/sat_2017.csv')
sat_17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_17.shape
# Out:
# (51, 5)

# %%
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_17[sat_17.columns[1:]] = sat_17[sat_17.columns[1:]].replace('[\%,]', '', regex=True).astype(float)

# %%
sat_17.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing   Math  \
# 0     Alabama            5.0                               593.0  572.0
# 1      Alaska           38.0                               547.0  533.0
# 2     Arizona           30.0                               563.0  553.0
# 3    Arkansas            3.0                               614.0  594.0
# 4  California           53.0                               531.0  524.0
#
#     Total
# 0  1165.0
# 1  1080.0
# 2  1116.0
# 3  1208.0
# 4  1055.0

# %%
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     float64
#  3   Math                                51 non-null     float64
#  4   Total                               51 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
sat_17.to_csv('../data/sat_17_cleaned.csv')

# %%
sat_act_by_college = pd.read_csv('../data/sat_act_by_college.csv')
sat_act_by_college.head()
# Out:
#                  School Test Optional? Applies to Class Year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile
# ...

# %%
sat_act_by_college.shape
# Out:
# (416, 8)

# %%
sat_act_by_college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   School                          416 non-null    object
#  1   Test Optional?                  416 non-null    object
#  2   Applies to Class Year(s)        390 non-null    object
#  3   Policy Details                  416 non-null    object
#  4   Number of Applicants            416 non-null    int64
#  5   Accept Rate                     416 non-null    object
#  6   SAT Total 25th-75th Percentile  416 non-null    object
#  7   ACT Total 25th-75th Percentile  416 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 26.1+ KB

# %%
sat_act_by_college['SAT Total 25th-75th Percentile'].unique()
# Out:
# array(['1440-1570', '1460-1580', '1450-1560', '1460-1570',
#        '\u200b\u200b 1530-1560', '\u200b\u200b 1500-1570',
#        '\u200b\u200b 1440-1570', '\u200b\u200b 1490-1570', '1390-1540',
#        '1440-1560', '1330-1520', '1450-1570', '1380-1540', '1440-1550',
#        '1460-1560', '1360-1510', '1470-1560', '1400-1560', '1410-1550',
#        '1340-1520', '1270-1480', '1290-1510', '1360-1520', '1350-1530',
#        '1350-1510', '1340-1490', '1300-1480', '1490-1570', '1370-1530',
#        '1300-1530', '1470-1570', '1360-1530', '1400-1550', '1283-1510',
#        '1370-1510', '1320-1510', '1370-1520', '1310-1485', '1350-1520',
#        '1360-1540', '1300-1510', '1348-1490', '1330-1500', '1300-1490',
#        '1340-1530', '1180-1440', '1340-1500', '1270-1450', '1280-1420',
#        '1370-1490', '1320-1470', '1290-1460', '1250-1420', '1290-1450',
#        '1300-1500', '1260-1460', '1320-1490', '1220-1400', '1250-1470',
# ...

# %%
sat_act_by_college[sat_act_by_college.columns[1:]].replace('\u200b\u200b ', '', regex=True).head()
# Out:
#   Test Optional? Applies to Class Year(s)  \
# 0            Yes                     2021
# 1            Yes                     2021
# 2            Yes                     2021
# 3            Yes                     2021
# 4            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile
# 0        4.3%                      1440-1570                          32-35
# 1        4.7%                      1460-1580                          33-35
# ...

# %%
sat_act_by_college['ACT Total 25th-75th Percentile'].unique()
# Out:
# array(['32-35', '33-35', '35-36', '34-36', '31-34', '31-35', '29-33',
#        '27-34', '31-33', '30-34', '30-33', '28-34', '32-34', '29-34',
#        '27-33', '26-32', '28-32', '--', '29-32', '25-33', '26-33',
#        '28-33', '27-31', '28-31', '22-29', '19-24', '27-32', '22-27',
#        '26-30', '27-30', '15-20', '20-26', '25-32', '25-31', '24-30',
#        '22-26', '19-25', '26-31', '23-29', '25-30', '24-29', '22-28',
#        '20-25', '24-31', '19-26', '19-27', '21-27', '21-26', '24-33',
#        '16-22', '21-28', '22-30', '23-30', '21-29', '23-28', '23-31',
#        '20-27', '17-23', '24-28.5', '15-19', '24-28', '17-22', '20-29',
#        '18-24', '19-28', '20-28', '19.3-25.3', '25-29', '17-24', '17-25',
#        '18-25'], dtype=object)

# %%
sat_act_by_college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   School                          416 non-null    object
#  1   Test Optional?                  416 non-null    object
#  2   Applies to Class Year(s)        390 non-null    object
#  3   Policy Details                  416 non-null    object
#  4   Number of Applicants            416 non-null    int64
#  5   Accept Rate                     416 non-null    object
#  6   SAT Total 25th-75th Percentile  416 non-null    object
#  7   ACT Total 25th-75th Percentile  416 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 26.1+ KB

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
sat_act_by_college.to_csv('../data/sat_act_by_college_cleaned.csv')

# %%
act_2019_ca = pd.read_csv('../data/act_2019_ca.csv')
act_2019_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
act_2019_ca.shape
# Out:
# (2310, 18)

# %%
act_2019_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1953 non-null   object
#  11  AvgScrEng    1953 non-null   object
#  12  AvgScrMath   1953 non-null   object
#  13  AvgScrSci    1953 non-null   object
#  14  NumGE21      1953 non-null   object
#  15  PctGE21      1953 non-null   object
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
act_2019_ca.drop(columns=['CDS', 'CCode', 'CDCode', 'SCode', 'RType'],inplace=True)

# %%
act_2019_ca['AvgScrRead'] = [np.nan if AvgScrRead=='*' else float(AvgScrRead) for AvgScrRead in act_2019_ca['AvgScrRead'].values]

# %%
act_2019_ca['AvgScrEng'] = [np.nan if AvgScrEng=='*' else float(AvgScrEng) for AvgScrEng in act_2019_ca['AvgScrEng'].values]

# %%
act_2019_ca['AvgScrMath'] = [np.nan if AvgScrMath=='*' else float(AvgScrMath) for AvgScrMath in act_2019_ca['AvgScrMath'].values]

# %%
act_2019_ca['AvgScrSci'] = [np.nan if AvgScrSci=='*' else float(AvgScrSci) for AvgScrSci in act_2019_ca['AvgScrSci'].values]

# %%
act_2019_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SName        1729 non-null   object
#  1   DName        2251 non-null   object
#  2   CName        2309 non-null   object
#  3   Enroll12     2309 non-null   float64
#  4   NumTstTakr   2309 non-null   float64
#  5   AvgScrRead   1421 non-null   float64
#  6   AvgScrEng    1421 non-null   float64
#  7   AvgScrMath   1421 non-null   float64
#  8   AvgScrSci    1421 non-null   float64
#  9   NumGE21      1953 non-null   object
#  10  PctGE21      1953 non-null   object
#  11  Year         2309 non-null   object
#  12  Unnamed: 17  0 non-null      float64
# dtypes: float64(7), object(6)
# memory usage: 234.7+ KB

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
act_2019_ca.to_csv('../data/act_2019_ca_cleaned.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.

# %% [markdown]
# Below is the example of 2019 ACT and SAT Data Dictionary.
#
# 2019 ACT Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**State**|*integer*|2019 ACT|State across US.|
# |**Participation**|*float*|2019 ACT|The percentage of student who join ACT exam by state.|
# |**Composite**|*float*|2019 ACT|The size of the population being tested. |

# %% [markdown]
# 2019 SAT Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**State**|*integer*|2019 SAT|State across US.|
# |**Participation**|*float*|2019 SAT|The percentage of student who join SAT exam by state.|
# |**EBRW**|*float*|2019 SAT|the Reading and Writing sections are combined to give you a final Evidence-Based Reading and Writing (EBRW) score on a scale of 200-800. |
# |**Math**|*float*|2019 SAT|The Math section is scored on a scale of 200-800. |
# |**Total**|*float*|2019 SAT|Total SAT score range of 400-1600. |

# %% [markdown]
# The rest of the dataset from 2017 and 2018 have the similar data dictionary entry as above. Below shows another example of data dictionary entry after merging of dataset from 2017 to 2019.

# %% [markdown]
# 2017-2019 ACT&SAT Data Dictionary Entry after merge:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**State**|*integer*|2017-2019 ACT&SAT|State across US.|
# |**Participation_19_x**|*float*|2019 ACT|The percentage of student who join ACT exam by state.|
# |**Composite_19**|*float*|2019 ACT|The size of the population being tested. |
# |**Participation_18_x**|*float*|2018 ACT|The percentage of student who join ACT exam by state.|
# |**Composite_18**|*float*|2018 ACT|The size of the population being tested. |
# |**Participation_17_x**|*float*|2017 ACT|The percentage of student who join ACT exam by state.|
# |**Composite_17**|*float*|2017 ACT|The size of the population being tested. |
# |**Participation_19_y**|*float*|2019 SAT|The percentage of student who join ACT exam by state.|
# |**Total_19**|*float*|2019 SAT|Total SAT score range of 400-1600. |
# |**Participation_18_y**|*float*|2018 SAT|The percentage of student who join ACT exam by state.|
# |**Total_18**|*float*|2018 SAT|Total SAT score range of 400-1600. |
# |**Participation_17_y**|*float*|2017 SAT|The percentage of student who join ACT exam by state.|
# |**Total_17**|*float*|2017 SAT|Total SAT score range of 400-1600. |

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Code:
act_19.describe()
# Out:
#        Participation  Composite
# count      52.000000  52.000000
# mean       58.538462  21.450000
# std        34.188326   2.175487
# min         6.000000  17.900000
# 25%        24.750000  19.800000
# 50%        53.000000  20.950000
# 75%       100.000000  23.650000
# max       100.000000  25.500000

# %%
#Code:
sat_19.describe()
# Out:
#        Participation        EBRW        Math        Total
# count      51.000000   51.000000   51.000000    51.000000
# mean       49.058824  560.803922  552.196078  1113.078431
# std        38.747600   46.248035   51.290553    97.197910
# min         2.000000  483.000000  460.000000   943.000000
# 25%         5.500000  527.500000  511.500000  1038.000000
# 50%        54.000000  550.000000  546.000000  1097.000000
# 75%        82.000000  612.000000  599.000000  1210.000000
# max       100.000000  636.000000  648.000000  1284.000000

# %%
act_19.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
def get_std_dev(act_19_col):
    n = len(act_19_col) - 1
    mean = sum(act_19_col) / n
    var = sum((x - mean)**2 for x in act_19_col) / n
    std_dev = var ** 0.5
    return std_dev

act_19_col = act_19['Participation']
round(get_std_dev(act_19_col))
# Out:
# 34

# %%
def get_std_dev(act_19_col):
    n = len(act_19_col) - 1
    mean = sum(act_19_col) / n
    var = sum((x - mean)**2 for x in act_19_col) / n
    std_dev = var ** 0.5
    return std_dev

act_19_col = act_19['Composite']
round(get_std_dev(act_19_col))
# Out:
# 2

# %%
round(act_19[['Participation', 'Composite']].std())
# Out:
# Participation    34.0
# Composite         2.0
# dtype: float64

# %%
col = ['Participation', 'Composite']
std = [34.0, 2.0]
sd = {key:std[n] for n, key in enumerate(col)}
sd
# Out:
# {'Participation': 34.0, 'Composite': 2.0}

# %%
sat_19.columns
# Out:
# Index(['State', 'Participation', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
def get_std_dev(sat_19_col):
    n = len(sat_19_col) - 1
    mean = sum(sat_19_col) / n
    var = sum((x - mean)**2 for x in sat_19_col) / n
    std_dev = var ** 0.5
    return std_dev

sat_19_col = sat_19['Participation']
round(get_std_dev(sat_19_col))
# Out:
# 39

# %%
def get_std_dev(sat_19_col):
    n = len(sat_19_col) - 1
    mean = sum(sat_19_col) / n
    var = sum((x - mean)**2 for x in sat_19_col) / n
    std_dev = var ** 0.5
    return std_dev

sat_19_col = sat_19['EBRW']
round(get_std_dev(sat_19_col))
# Out:
# 48

# %%
def get_std_dev(sat_19_col):
    n = len(sat_19_col) - 1
    mean = sum(sat_19_col) / n
    var = sum((x - mean)**2 for x in sat_19_col) / n
    std_dev = var ** 0.5
    return std_dev

sat_19_col = sat_19['Math']
round(get_std_dev(sat_19_col))
# Out:
# 52

# %%
def get_std_dev(sat_19_col):
    n = len(sat_19_col) - 1
    mean = sum(sat_19_col) / n
    var = sum((x - mean)**2 for x in sat_19_col) / n
    std_dev = var ** 0.5
    return std_dev

sat_19_col = sat_19['Total']
round(get_std_dev(sat_19_col))
# Out:
# 100

# %%
round(sat_19[['Participation', 'EBRW', 'Math', 'Total']].std())
# Out:
# Participation    39.0
# EBRW             46.0
# Math             51.0
# Total            97.0
# dtype: float64

# %%
col = ['Participation', 'EBRW', 'Math', 'Total' ]
std = [39.0, 46.0, 51.0, 97.0]
sd = {key:std[n] for n, key in enumerate(col)}
sd
# Out:
# {'Participation': 39.0, 'EBRW': 46.0, 'Math': 51.0, 'Total': 97.0}

# %%
act_19.sort_values('Participation', ascending=False).head(15)
# Out:
#              State  Participation  Composite
# 0          Alabama          100.0       18.9
# 17        Kentucky          100.0       19.8
# 50         Wyoming          100.0       19.8
# 49       Wisconsin          100.0       20.3
# 44            Utah          100.0       20.3
# 42       Tennessee          100.0       19.4
# 36        Oklahoma          100.0       18.9
# 35            Ohio          100.0       20.0
# 33  North Carolina          100.0       19.0
# 28          Nevada          100.0       17.9
# 27        Nebraska          100.0       20.0
# 24     Mississippi          100.0       18.4
# 18       Louisiana          100.0       18.8
# 26         Montana          100.0       19.8
# 3         Arkansas          100.0       19.3

# %%
sat_19.sort_values('Participation', ascending=False).head(8)
# Out:
#            State  Participation   EBRW   Math   Total
# 40  Rhode Island          100.0  503.0  492.0   995.0
# 13      Illinois          100.0  509.0  504.0  1013.0
# 22      Michigan          100.0  507.0  496.0  1003.0
# 5       Colorado          100.0  518.0  506.0  1024.0
# 6    Connecticut          100.0  529.0  516.0  1046.0
# 7       Delaware          100.0  499.0  486.0   985.0
# 9        Florida          100.0  516.0  483.0   999.0
# 12         Idaho          100.0  505.0  488.0   993.0

# %%
act_19.sort_values('Participation').head()
# Out:
#             State  Participation  Composite
# 19          Maine            6.0       24.3
# 39   Rhode Island           12.0       24.7
# 7        Delaware           13.0       24.1
# 29  New Hampshire           14.0       25.0
# 38   Pennsylvania           17.0       23.6

# %%
sat_19.sort_values('Participation').head()
# Out:
#            State  Participation   EBRW   Math   Total
# 34  North Dakota            2.0  627.0  636.0  1263.0
# 52       Wyoming            3.0  623.0  615.0  1238.0
# 42  South Dakota            3.0  633.0  635.0  1268.0
# 27      Nebraska            3.0  628.0  631.0  1260.0
# 51     Wisconsin            3.0  635.0  648.0  1283.0

# %% [markdown]
# By examined 2019 data, it shows that 2019 ACT highest participation rate is 100 percent. Total of 15 states achieve the 100 percent rate, which are Alabama, Kentucky, Wyoming. Wisconsin, Utah, Tennessee, Oklahoma, Ohio, North Carolina, Nevada, Nebraska, Mississippi, Louisiana, Montana and Arkansas.
#
# 2019 SAT highest participation rate is 100 percent. Total of 8 states achieve the 100 percent rate, which are Rhode Island, Illinois, Michigan, Colorado, Connecticut, Delaware, Florida and Idaho.
#
# 2019 ACT lowest participation rate 6.0 percent which is Maine.
#
# 2019 SAT lowest participation rate 2.0 percent which is North Dakota.

# %%
act_19.sort_values('Composite', ascending=False).head()
# Out:
#             State  Participation  Composite
# 21  Massachusetts           21.0       25.5
# 6     Connecticut           22.0       25.5
# 29  New Hampshire           14.0       25.0
# 39   Rhode Island           12.0       24.7
# 32       New York           22.0       24.5

# %%
sat_19.sort_values('Total', ascending=False).head()
# Out:
#            State  Participation   EBRW   Math   Total
# 23     Minnesota            4.0  636.0  648.0  1284.0
# 51     Wisconsin            3.0  635.0  648.0  1283.0
# 42  South Dakota            3.0  633.0  635.0  1268.0
# 34  North Dakota            2.0  627.0  636.0  1263.0
# 27      Nebraska            3.0  628.0  631.0  1260.0

# %%
act_19.sort_values('Composite').head()
# Out:
#              State  Participation  Composite
# 28          Nevada          100.0       17.9
# 24     Mississippi          100.0       18.4
# 18       Louisiana          100.0       18.8
# 40  South Carolina           78.0       18.8
# 36        Oklahoma          100.0       18.9

# %%
sat_19.sort_values('Total').head()
# Out:
#                    State  Participation   EBRW   Math  Total
# 50         West Virginia           99.0  483.0  460.0  943.0
# 36              Oklahoma           22.0  490.0  472.0  963.0
# 8   District of Columbia           94.0  495.0  480.0  975.0
# 7               Delaware          100.0  499.0  486.0  985.0
# 12                 Idaho          100.0  505.0  488.0  993.0

# %% [markdown]
# By examined 2019 data, it shows that 2019 ACT highest mean composiste is 25.5 contributed by the states Massachusetts and Connecticut.
#
# 2019 SAT highest mean total is 1284.0 contributed by the states of Minnesota.
#
# 2019 ACT lowest mean composiste is 17.9 which is from the state of Nevada.
#
# 2019 SAT lowest mean total is 943.0 which is from the states of West Virginia.

# %%
act_18_19 = pd.merge(act_19, act_18, on = 'State', how = 'inner')

# %%
act_18_19.head()
# Out:
#         State  Participation_x  Composite_x  Participation_y  Composite_y
# 0     Alabama            100.0         18.9            100.0         19.1
# 1      Alaska             38.0         20.1             33.0         20.8
# 2     Arizona             73.0         19.0             66.0         19.2
# 3    Arkansas            100.0         19.3            100.0         19.4
# 4  California             23.0         22.6             27.0         22.7

# %%
act_17_18_19 = pd.merge(act_18_19, act_17, on = 'State', how = 'inner')

# %%
act_17_18_19.head()
# Out:
#         State  Participation_x  Composite_x  Participation_y  Composite_y  \
# 0     Alabama            100.0         18.9            100.0         19.1
# 1      Alaska             38.0         20.1             33.0         20.8
# 2     Arizona             73.0         19.0             66.0         19.2
# 3    Arkansas            100.0         19.3            100.0         19.4
# 4  California             23.0         22.6             27.0         22.7
#
#    Participation  English  Math  Reading  Science  Composite
# 0          100.0     18.9  18.4     19.7     19.4       19.2
# 1           65.0     18.7  19.8     20.4     19.9       19.8
# 2           62.0     18.6  19.8     20.1     19.8       19.7
# 3          100.0     18.9  19.0     19.7     19.5       19.4
# 4           31.0     22.5  22.7     23.1     22.2       22.8

# %%
act_17_18_19.loc[(act_17_18_19.Participation_x == 100)|(act_17_18_19.Participation_y == 100)|(act_17_18_19.Participation == 100), :].sort_values('Participation_x', ascending=False)
# Out:
#              State  Participation_x  Composite_x  Participation_y  \
# 0          Alabama            100.0         18.9            100.0
# 3         Arkansas            100.0         19.3            100.0
# 49       Wisconsin            100.0         20.3            100.0
# 44            Utah            100.0         20.3            100.0
# 42       Tennessee            100.0         19.4            100.0
# 36        Oklahoma            100.0         18.9            100.0
# 35            Ohio            100.0         20.0            100.0
# 33  North Carolina            100.0         19.0            100.0
# 28          Nevada            100.0         17.9            100.0
# 27        Nebraska            100.0         20.0            100.0
# 26         Montana            100.0         19.8            100.0
# 24     Mississippi            100.0         18.4            100.0
# 17       Louisiana            100.0         18.8            100.0
# ...

# %%
sat_18_19 = pd.merge(sat_19, sat_18, on = 'State', how = 'inner')

# %%
sat_18_19.head()
# Out:
#         State  Participation_x   EBRW  Math_x  Total_x  Participation_y  \
# 0     Alabama              7.0  583.0   560.0   1143.0              6.0
# 1      Alaska             41.0  556.0   541.0   1097.0             43.0
# 2     Arizona             31.0  569.0   565.0   1134.0             29.0
# 3    Arkansas              6.0  582.0   559.0   1141.0              5.0
# 4  California             63.0  534.0   531.0   1065.0             60.0
#
#    Evidence-Based Reading and Writing  Math_y  Total_y
# 0                               595.0   571.0   1166.0
# 1                               562.0   544.0   1106.0
# 2                               577.0   572.0   1149.0
# 3                               592.0   576.0   1169.0
# 4                               540.0   536.0   1076.0

# %%
sat_17_18_19 = pd.merge(sat_18_19, sat_17, on = 'State', how = 'inner')

# %%
sat_17_18_19.head()
# Out:
#         State  Participation_x   EBRW  Math_x  Total_x  Participation_y  \
# 0     Alabama              7.0  583.0   560.0   1143.0              6.0
# 1      Alaska             41.0  556.0   541.0   1097.0             43.0
# 2     Arizona             31.0  569.0   565.0   1134.0             29.0
# 3    Arkansas              6.0  582.0   559.0   1141.0              5.0
# 4  California             63.0  534.0   531.0   1065.0             60.0
#
#    Evidence-Based Reading and Writing_x  Math_y  Total_y  Participation  \
# 0                                 595.0   571.0   1166.0            5.0
# 1                                 562.0   544.0   1106.0           38.0
# 2                                 577.0   572.0   1149.0           30.0
# 3                                 592.0   576.0   1169.0            3.0
# 4                                 540.0   536.0   1076.0           53.0
#
#    Evidence-Based Reading and Writing_y   Math   Total
# ...

# %%
sat_17_18_19.loc[(sat_17_18_19.Participation_x == 100)|(sat_17_18_19.Participation_y == 100)|(sat_17_18_19.Participation == 100), :].sort_values('Participation_x', ascending=False)
# Out:
#                    State  Participation_x   EBRW  Math_x  Total_x  \
# 5               Colorado            100.0  518.0   506.0   1024.0
# 6            Connecticut            100.0  529.0   516.0   1046.0
# 7               Delaware            100.0  499.0   486.0    985.0
# 9                Florida            100.0  516.0   483.0    999.0
# 12                 Idaho            100.0  505.0   488.0    993.0
# 13              Illinois            100.0  509.0   504.0   1013.0
# 22              Michigan            100.0  507.0   496.0   1003.0
# 39          Rhode Island            100.0  503.0   492.0    995.0
# 8   District of Columbia             94.0  495.0   480.0    975.0
#
#     Participation_y  Evidence-Based Reading and Writing_x  Math_y  Total_y  \
# 5             100.0                                 519.0   506.0   1025.0
# 6             100.0                                 535.0   519.0   1053.0
# 7             100.0                                 505.0   492.0    998.0
# ...

# %% [markdown]
# The 100% participation rate on ACT were changed from year 2017 to 2019. The states are Minnesota, Missouri, South Carolina and Colorado.
#
# For SAT, there are 3 states show improving participation rate from year 2017 to 2019, which are Florida, Illinois and Rhode Island. However, there are one state show decreasing trend in 100% participation rate from year 2017 to 2019, which is District of Columbia.

# %%
act_17_18_19.rename(columns={
    'Participation_x': 'Participation_19', 
    'Composite_x': 'Composite_19',
    'Participation_y': 'Participation_18', 
    'Composite_y': 'Composite_18', 
    'Participation': 'Participation_17', 
    'Composite': 'Composite_17'
}, inplace=True)

# %%
act_17_18_19.head()
# Out:
#         State  Participation_19  Composite_19  Participation_18  Composite_18  \
# 0     Alabama             100.0          18.9             100.0          19.1
# 1      Alaska              38.0          20.1              33.0          20.8
# 2     Arizona              73.0          19.0              66.0          19.2
# 3    Arkansas             100.0          19.3             100.0          19.4
# 4  California              23.0          22.6              27.0          22.7
#
#    Participation_17  English  Math  Reading  Science  Composite_17
# 0             100.0     18.9  18.4     19.7     19.4          19.2
# 1              65.0     18.7  19.8     20.4     19.9          19.8
# 2              62.0     18.6  19.8     20.1     19.8          19.7
# 3             100.0     18.9  19.0     19.7     19.5          19.4
# 4              31.0     22.5  22.7     23.1     22.2          22.8

# %%
act_17_18_19.drop(columns=['English', 'Math', 'Reading', 'Science'],inplace=True)

# %%
act_17_18_19.head()
# Out:
#         State  Participation_19  Composite_19  Participation_18  Composite_18  \
# 0     Alabama             100.0          18.9             100.0          19.1
# 1      Alaska              38.0          20.1              33.0          20.8
# 2     Arizona              73.0          19.0              66.0          19.2
# 3    Arkansas             100.0          19.3             100.0          19.4
# 4  California              23.0          22.6              27.0          22.7
#
#    Participation_17  Composite_17
# 0             100.0          19.2
# 1              65.0          19.8
# 2              62.0          19.7
# 3             100.0          19.4
# 4              31.0          22.8

# %%
sat_17_18_19.rename(columns={
    'Participation_x': 'Participation_19', 
    'Total_x': 'Total_19',
    'Participation_y': 'Participation_18', 
    'Total_y': 'Total_18', 
    'Participation': 'Participation_17', 
    'Total': 'Total_17'
}, inplace=True)

# %%
sat_17_18_19.head()
# Out:
#         State  Participation_19   EBRW  Math_x  Total_19  Participation_18  \
# 0     Alabama               7.0  583.0   560.0    1143.0               6.0
# 1      Alaska              41.0  556.0   541.0    1097.0              43.0
# 2     Arizona              31.0  569.0   565.0    1134.0              29.0
# 3    Arkansas               6.0  582.0   559.0    1141.0               5.0
# 4  California              63.0  534.0   531.0    1065.0              60.0
#
#    Evidence-Based Reading and Writing_x  Math_y  Total_18  Participation_17  \
# 0                                 595.0   571.0    1166.0               5.0
# 1                                 562.0   544.0    1106.0              38.0
# 2                                 577.0   572.0    1149.0              30.0
# 3                                 592.0   576.0    1169.0               3.0
# 4                                 540.0   536.0    1076.0              53.0
#
#    Evidence-Based Reading and Writing_y   Math  Total_17
# ...

# %%
sat_17_18_19.drop(columns=['EBRW', 'Math_x', 'Evidence-Based Reading and Writing_x', 'Math_y', 'Evidence-Based Reading and Writing_y', 'Math'],inplace=True)

# %%
sat_17_18_19.head()
# Out:
#         State  Participation_19  Total_19  Participation_18  Total_18  \
# 0     Alabama               7.0    1143.0               6.0    1166.0
# 1      Alaska              41.0    1097.0              43.0    1106.0
# 2     Arizona              31.0    1134.0              29.0    1149.0
# 3    Arkansas               6.0    1141.0               5.0    1169.0
# 4  California              63.0    1065.0              60.0    1076.0
#
#    Participation_17  Total_17
# 0               5.0    1165.0
# 1              38.0    1080.0
# 2              30.0    1116.0
# 3               3.0    1208.0
# 4              53.0    1055.0

# %%
act_sat = pd.merge(act_17_18_19, sat_17_18_19, on = 'State', how = 'inner')

# %%
act_sat.head()
# Out:
#         State  Participation_19_x  Composite_19  Participation_18_x  \
# 0     Alabama               100.0          18.9               100.0
# 1      Alaska                38.0          20.1                33.0
# 2     Arizona                73.0          19.0                66.0
# 3    Arkansas               100.0          19.3               100.0
# 4  California                23.0          22.6                27.0
#
#    Composite_18  Participation_17_x  Composite_17  Participation_19_y  \
# 0          19.1               100.0          19.2                 7.0
# 1          20.8                65.0          19.8                41.0
# 2          19.2                62.0          19.7                31.0
# 3          19.4               100.0          19.4                 6.0
# 4          22.7                31.0          22.8                63.0
#
#    Total_19  Participation_18_y  Total_18  Participation_17_y  Total_17
# ...

# %%
act_sat.loc[(act_sat.Participation_19_x > 50)&(act_sat.Participation_19_y > 50), :].sort_values('State', ascending=False)
# Out:
#              State  Participation_19_x  Composite_19  Participation_18_x  \
# 40  South Carolina                78.0          18.8               100.0
# 33  North Carolina               100.0          19.0               100.0
# 10          Hawaii                80.0          19.0                89.0
# 8          Florida                54.0          20.1                66.0
#
#     Composite_18  Participation_17_x  Composite_17  Participation_19_y  \
# 40          18.3               100.0          18.7                68.0
# 33          19.1               100.0          19.1                51.0
# 10          18.9                90.0          19.0                54.0
# 8           19.9                73.0          19.8               100.0
#
#     Total_19  Participation_18_y  Total_18  Participation_17_y  Total_17
# 40    1030.0                55.0    1070.0                50.0    1064.0
# 33    1100.0                52.0    1098.0                49.0    1081.0
# ...

# %%
act_sat.loc[(act_sat.Participation_18_x > 50)&(act_sat.Participation_18_y > 50), :].sort_values('State', ascending=False)
# Out:
#              State  Participation_19_x  Composite_19  Participation_18_x  \
# 40  South Carolina                78.0          18.8               100.0
# 33  North Carolina               100.0          19.0               100.0
# 10          Hawaii                80.0          19.0                89.0
# 9          Georgia                49.0          21.4                53.0
# 8          Florida                54.0          20.1                66.0
#
#     Composite_18  Participation_17_x  Composite_17  Participation_19_y  \
# 40          18.3               100.0          18.7                68.0
# 33          19.1               100.0          19.1                51.0
# 10          18.9                90.0          19.0                54.0
# 9           21.4                55.0          21.4                71.0
# 8           19.9                73.0          19.8               100.0
#
#     Total_19  Participation_18_y  Total_18  Participation_17_y  Total_17
# ...

# %%
act_sat.loc[(act_sat.Participation_17_x > 50)&(act_sat.Participation_17_y > 50), :].sort_values('State', ascending=False)
# Out:
#       State  Participation_19_x  Composite_19  Participation_18_x  \
# 10   Hawaii                80.0          19.0                89.0
# 9   Georgia                49.0          21.4                53.0
# 8   Florida                54.0          20.1                66.0
#
#     Composite_18  Participation_17_x  Composite_17  Participation_19_y  \
# 10          18.9                90.0          19.0                54.0
# 9           21.4                55.0          21.4                71.0
# 8           19.9                73.0          19.8               100.0
#
#     Total_19  Participation_18_y  Total_18  Participation_17_y  Total_17
# 10    1100.0                56.0    1010.0                55.0    1085.0
# 9     1058.0                70.0    1064.0                61.0    1050.0
# 8      999.0                56.0    1099.0                83.0    1017.0

# %% [markdown]
# In year 2019, there are 4 states show >50% participation on both tests, which are South Carolina, North Carolina, Hawaii and Florida.
#
# In year 2018, there are 5 states show >50% participation on both tests, which are South Carolina, North Carolina, Hawaii, Georgia and Florida.
#
# In year 2017, there are 3 states show >50% participation on both tests, which are Hawaii, Georgia and Florida.

# %%
sat_act_by_college.sort_values('ACT Total 25th-75th Percentile', ascending=False).head()
# Out:
#                                    School Test Optional?  \
# 5      California Institute of Technology       Yes (TB)
# 6   Massachusetts Institute of Technology            Yes
# 18               Johns Hopkins University            Yes
# 16                  Vanderbilt University            Yes
# 37             Carnegie Mellon University            Yes
#
#    Applies to Class Year(s)  \
# 5                 2021 2022
# 6                      2021
# 18                     2021
# 16                     2021
# 37                     2021
#
#                                        Policy Details  Number of Applicants  \
# 5   CalTech has adopted a two-year Test Blind poli...                  8367
# 6   MIT has adopted a one-year test optional polic...                 21706
# 18  Johns Hopkins has adopted a one-year test opti...                 29129
# 16  Vanderbilthas adopted a one-year test optional...                 37310
# ...

# %%
sat_act_by_college.sort_values('SAT Total 25th-75th Percentile', ascending=False).head()
# Out:
#                                     School Test Optional?  \
# 5       California Institute of Technology       Yes (TB)
# 6    Massachusetts Institute of Technology            Yes
# 8                    University of Chicago            Yes
# 7                         Brown University            Yes
# 280                    University of Akron            Yes
#
#     Applies to Class Year(s)  \
# 5                  2021 2022
# 6                       2021
# 8     All / Permanent Policy
# 7                       2021
# 280                     2021
#
#                                         Policy Details  Number of Applicants  \
# 5    CalTech has adopted a two-year Test Blind poli...                  8367
# 6    MIT has adopted a one-year test optional polic...                 21706
# 8    UChicago offers a test optional policy which a...                 32283
# 7    Brown has adopted a one-year test optional pol...                 38674
# ...

# %% [markdown]
# California Institute of Technology have the highest median SAT and ACT scores for admittance.

# %%
act_2019_ca['Composite'] = round((act_2019_ca['AvgScrRead']+act_2019_ca['AvgScrEng']+act_2019_ca['AvgScrMath']+act_2019_ca['AvgScrSci'])/4)

# %%
act_2019_ca.sort_values('Composite', ascending=False).head()
# Out:
#                       SName                                DName        CName  \
# 926           Lynbrook High                   Fremont Union High  Santa Clara
# 1025       Monta Vista High                   Fremont Union High  Santa Clara
# 1760         Oxford Academy                   Anaheim Union High       Orange
# 1992          Saratoga High  Los Gatos-Saratoga Joint Union High  Santa Clara
# 1006  Mission San Jose High                      Fremont Unified      Alameda
#
#       Enroll12  NumTstTakr  AvgScrRead  AvgScrEng  AvgScrMath  AvgScrSci  \
# 926      415.0       172.0        32.0       32.0        32.0       31.0
# 1025     584.0       212.0        31.0       32.0        32.0       31.0
# 1760     200.0        56.0        31.0       32.0        30.0       30.0
# 1992     321.0       121.0        31.0       32.0        31.0       30.0
# 1006     490.0       157.0        31.0       32.0        32.0       30.0
#
#      NumGE21 PctGE21     Year  Unnamed: 17  Composite
# ...

# %%
act_2019_ca.sort_values('Composite').head()
# Out:
#                                                  SName                DName  \
# 310                         Citrus High (Continuation)      Fontana Unified
# 539                     Eric Birch High (Continuation)      Fontana Unified
# 129  Augustus F. Hawkins High B Community Health Ad...  Los Angeles Unified
# 266                                    Centennial High      Compton Unified
# 599                                       Fremont High      Oakland Unified
#
#               CName  Enroll12  NumTstTakr  AvgScrRead  AvgScrEng  AvgScrMath  \
# 310  San Bernardino     181.0       103.0        12.0       10.0        14.0
# 539  San Bernardino     142.0       113.0        13.0       11.0        14.0
# 129     Los Angeles      93.0        25.0        15.0       13.0        15.0
# 266     Los Angeles     214.0       153.0        14.0       13.0        15.0
# 599         Alameda     154.0        26.0        14.0       14.0        15.0
#
# ...

# %% [markdown]
# Lynbrook High and Monta Vista High have the highest mean test while Citrus High (Continuation) has the lowest mean test score in 2019 ACT.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
act_sat_df = act_sat.rename(index=str, columns={"Participation_19_x": "ACT Participation 19",
                                                "Participation_18_x": "ACT Participation 18",
                                                "Participation_17_x": "ACT Participation 17",
                                                "Composite_19": "ACT Composite 19",
                                                "Composite_18": "ACT Composite 18",
                                                "Composite_17": "ACT Composite 17",
                                                "Participation_19_y": "SAT Participation 19", 
                                                "Participation_18_y": "SAT Participation 18",
                                                "Participation_17_y": "SAT Participation 17",
                                                "Total_19": "SAT Total 19",
                                                "Total_18": "SAT Total 18",
                                                "Total_17": "SAT Total 17",
                                                "State": "State"})
act_sat_df.head()
# Out:
#         State  ACT Participation 19  ACT Composite 19  ACT Participation 18  \
# 0     Alabama                 100.0              18.9                 100.0
# 1      Alaska                  38.0              20.1                  33.0
# 2     Arizona                  73.0              19.0                  66.0
# 3    Arkansas                 100.0              19.3                 100.0
# 4  California                  23.0              22.6                  27.0
#
#    ACT Composite 18  ACT Participation 17  ACT Composite 17  \
# 0              19.1                 100.0              19.2
# 1              20.8                  65.0              19.8
# 2              19.2                  62.0              19.7
# 3              19.4                 100.0              19.4
# 4              22.7                  31.0              22.8
#
#    SAT Participation 19  SAT Total 19  SAT Participation 18  SAT Total 18  \
# ...

# %%
plt.figure(figsize = (16,9))

corr = act_sat_df.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)

# %% [markdown]
# The correlation of SAT and ACT participation rates show negatively correlated to each other from year 2017 to 2019. For example, the correlation between ACT Participation 19 and SAT Participation 19 are -87% correlated to each other. This means that states that have high ACT participation rates tend to have low SAT participation rates and vice versa.
#
# The correlation of participation rate and scores also show negatively correlated in ACT/SAT from year 2017 to 2019. In the instance of SAT Participation 17 versus SAT Total 17, the correlation are -86%. This imply that high participation rate tend to lower down the scores in test.

# %%
act_sat_df[['ACT Participation 19','SAT Participation 19' ,'ACT Participation 18', 'SAT Participation 18','ACT Participation 17' ,'SAT Participation 17']].hist(figsize=(16,8));

# %% [markdown]
# 3 histograms are plotted for ACT year 2017-2019 on the left while another 3 histograms are plotted for SAT year 2017-2019 on the right. For ACT test, it shows peak at the right as the 100% participation rate show higher frequency. However, for SAT test, it shows peak at the left as the 100% participation rate are lower as compared to ACT test. The distribution are not normal for both SAT and ACT. Low participation was prevalent with the SAT for year 2017-2019 as compared to ACT test.

# %%
fig, ax = plt.subplots(1,2,figsize=(10, 10), sharey=True)
plt.subplots_adjust(wspace=0.03)

# SAT participation 2017
df = act_sat_df.sort_values(by='SAT Participation 17',ascending=False)
sns.barplot(y='State', x='SAT Participation 17',data=df,color='skyblue',ax=ax[0])
ax[0].set_title('2017 SAT',fontsize=16)
ax[0].set_xlabel('')
ax[0].invert_xaxis()

# ACT participation 2017
sns.barplot(y='State', x='ACT Participation 17',data=df,color='orange', ax=ax[1])
ax[1].set_title('2017 ACT',fontsize=16)
ax[1].set_xlabel('')
ax[1].set_ylabel('')

fig, ax = plt.subplots(1,2,figsize=(10, 10), sharey=True)
plt.subplots_adjust(wspace=0.03)

# SAT participation 2018
df = act_sat_df.sort_values(by='SAT Participation 18',ascending=False)
sns.barplot(y='State', x='SAT Participation 18',data=df,color='skyblue',ax=ax[0])
ax[0].set_title('2018 SAT',fontsize=16)
ax[0].set_xlabel('')
ax[0].invert_xaxis()

# ACT participation 2018
sns.barplot(y='State', x='ACT Participation 18',data=df,color='orange', ax=ax[1])
ax[1].set_title('2018 ACT',fontsize=16)
ax[1].set_xlabel('')
ax[1].set_ylabel('')

fig, ax = plt.subplots(1,2,figsize=(10, 10), sharey=True)
plt.subplots_adjust(wspace=0.03)

# SAT participation 2019
df = act_sat_df.sort_values(by='SAT Participation 19',ascending=False)
sns.barplot(y='State', x='SAT Participation 19',data=df,color='skyblue',ax=ax[0])
ax[0].set_title('2019 SAT',fontsize=16)
ax[0].set_xlabel('')
ax[0].invert_xaxis()

# ACT participation 2019
sns.barplot(y='State', x='ACT Participation 19',data=df,color='orange', ax=ax[1])
ax[1].set_title('2019 ACT',fontsize=16)
ax[1].set_xlabel('')
ax[1].set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# With the 3 barplots shown above from year 2017 to year 2019, there are increase in state by achieving 100% participation rate for SAT. There were only 3 states shown 100% participation rate in year 2017. It further increased to 5 states by year 2018 and 8 states by year 2019. In contrast, although ACT had higher participation rate but it shown decreasing trend in participation rate. There were 17 states achieved 100% participation rate in 2017 and 2018, however, it dropped to 15 states in 2019.

# %%
# set lists to split dataframe for plots
sat_scores = ['SAT Total 17','SAT Total 18','SAT Total 19']
act_scores = ['ACT Composite 17','ACT Composite 18', 'ACT Composite 19']
sat_participation = ['SAT Participation 17','SAT Participation 18','SAT Participation 19']
act_participation = ['ACT Participation 17', 'ACT Participation 18', 'ACT Participation 19']

fig, ax = plt.subplots(2,2, figsize=(15, 10)) 

sns.boxplot(data=act_sat_df[sat_scores],ax = ax[0][0],orient='h')
ax[0][0].set_title('SAT Total Scores (2017 to 2019)',fontsize=16)
plt.setp(ax[0][0].get_xticklabels(), fontsize=14)

sns.boxplot(data=act_sat_df[act_scores],ax = ax[0][1],orient='h')
ax[0][1].set_title('ACT Composite (2017 to 2019)',fontsize=16)
plt.setp(ax[0][1].get_xticklabels(), fontsize=14)

sns.boxplot(data=act_sat_df[sat_participation],ax = ax[1][0],orient='h')
ax[1][0].set_title('SAT participations (2017 to 2019)',fontsize=16)
plt.setp(ax[1][0].get_xticklabels(), fontsize=14)

sns.boxplot(data=act_sat_df[act_participation],ax = ax[1][1],orient='h')
ax[1][1].set_title('ACT participations (2017 to 2019)',fontsize=16)
plt.setp(ax[1][1].get_xticklabels(), fontsize=14)

plt.tight_layout()

# %% [markdown]
# In addition to the summary statistics and historgrams above, these boxplots illustrate the distribution of participation rates and scores.The SAT score distributions between 2017 and 2018 were largely similar. Except distribution in 2019, it shows much lower total were scored in year 2019. For ACT, the score distributions were largely similar as well with no big variations.
# Comparing SAT and ACT participation rates, SAT participations have a lower median between 2017 and 2018, indicating that more states had higher participation rates for ACT. However, SAT shows higher median in year 2019 as compared to ACT participation. This indicates that there is increase in participating SAT test.

# %%
# custom function for drawing scatterplot
def scatterplot(dataframe, col1, col2, title,color=None):
    sns.regplot(x=dataframe[col1],y=dataframe[col2],
                scatter_kws={'facecolors':color,'edgecolor':color},
                line_kws = {'color':'grey'})
    plt.title(title,fontsize=14)
    plt.xlabel(col1,fontsize=12)
    plt.ylabel(col2,fontsize=12)

# %%
plt.figure(figsize=(15,3.5))

# Scatterplot: participation rate vs score (SAT 2017)
plt.subplot(1,4,1)
scatterplot(act_sat_df,'SAT Participation 17','SAT Total 17','Participation vs Score (SAT 2017)')
# Scatterplot: participation rate vs score (SAT 2018)
plt.subplot(1,4,2)
scatterplot(act_sat_df,'SAT Participation 18','SAT Total 18','Participation vs Score (SAT 2018)')
# Scatterplot: participation rate vs score (SAT 2019)
plt.subplot(1,4,3)
scatterplot(act_sat_df,'SAT Participation 19','SAT Total 19','Participation vs Score (SAT 2019)')
            
plt.tight_layout()

# %%
plt.figure(figsize=(15,3.5))
plt.subplot(1,4,1)
scatterplot(act_sat_df,'ACT Participation 17','ACT Composite 17','Participation vs Score (ACT 2017)')
plt.subplot(1,4,2)
scatterplot(act_sat_df,'ACT Participation 18','ACT Composite 18','Participation vs Score (ACT 2018)')
plt.subplot(1,4,3)
scatterplot(act_sat_df,'ACT Participation 19','ACT Composite 19','Participation vs Score (ACT 2019)')
plt.tight_layout()

# %% [markdown]
# The participation rate were further examined with score to understand the correlation in between. Both SAT and ACT subplot show that high participation rate are associated with low composite/total score while low participation rate are associated with high composite/total score. Therefore, it can be concluded that participation rate are negatively correlated to score in both SAT and ACT.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# From the above analysis, the key takeaways are:
#
# - High participation rates in one test usually means low participation rates in the other. The states that have high SAT participation rates tend to have low ACT participation rates and vice versa.
# - Participation rates are negatively correlated with test scores. This suggests that the higher the participation rate, the lower the average. This probably occurs because in cases of low participation only highly motivated students are likely to take exams. High participation rates bring in a wider range of student skills lowering the average.
# - Generally, low participation was prevalent with the SAT as compared to ACT test. However, the participation rate in SAT have increased in year 2019 by comparing the 2019 SAT/ACT participation median.

# %% [markdown]
# Recommendation to improve SAT participation rate:
#
# - SAT is more popular among the coastal states, whereas ACT is more popular inland. Based on both an examination of the data and a review of state college entrance exam testing policy, it is clear that participation in such tests is heavily influenced by state policy towards testing. Therefore, we recommend to target those school which have not already done so can consider making SAT as mandatory high school graduation requirement. In this project, we recommend to target Iowa as it has one of the lowest overall participation rate for SAT based on our data.
